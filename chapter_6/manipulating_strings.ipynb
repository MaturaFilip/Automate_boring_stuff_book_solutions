# %% [markdown]
# ![Screenshot_20240820_201922.png](attachment:243201f8-429d-4c99-ae4b-ef48032ea456.png)

# %% [markdown]
# ## Raw strings
#
# A raw string completely ignores all escape characters
# and prints any backslash that appears in the string.

# %% [markdown]
# ## Triple ''' or """
#
# no need to use escape -> If you write on the next line, it will be on the next line

# %% [markdown]
# ## f string -> znáš

# %% [markdown]
# # Useful strings methods
#
# - The upper(), lower(), isupper(), and islower() Methods
#
# -  these methods do not change the string itself but return
# new string values.

# %% [markdown]
# ![Screenshot_20240820_211330.png](attachment:b9b3c4f4-a976-4bdc-9131-236aa4527f7b.png)

# %% [markdown]
# ### The startswith() and endswith() Methods
#
# - return true or false
# - These methods are useful alternatives to the == equals operator if you
# need to check only whether the first or last part of the string, rather than
# the whole thing, is equal to another string.

# %% [markdown]
# ## The join() and split() Methods!!!!!!!!! [IMPORTANT]

# %% [markdown]
# join() -> join list of strings

# %%
 ' '.join(['My', 'name', 'is', 'Simon'])
# Out:
# 'My name is Simon'

# %% [markdown]
# The split()
# method does the opposite: It’s called on a string value and returns a list of
# strings.

# %%
'My name is Simon'.split()
# Out:
# ['My', 'name', 'is', 'Simon']

# %%
# spam.split('\n') -> split by new line

# %% [markdown]
# ## Splitting Strings with the partition() Method
#
# -The partition() string method can split a string into the text before and
# after a separator string.
# - returns tuple with 3 substring
# - - more time -> split only first occurence

# %%
'Hello, world!'.partition('w')
# Out:
# ('Hello, ', 'w', 'orld!')

# %%
#You can use the multiple assignment trick to assign the three returned
#strings to three variables:

a, b, c = 'Hello, world!'.partition('w')



c
# Out:
# 'orld!'

# %%
a
# Out:
# 'Hello, '

# %% [markdown]
# ## Justifying Text with the rjust(), ljust(), and center() Methods
#
# - posune text doleva nebo doprava podle toho jaké číslo dáš do závorky
# - These methods are especially useful when you need to print tabular
# data that has correct spacing.

# %%
'Hello'.rjust(10)
# Out:
# '     Hello'

# %%
# justify with othr than space
'Hello'.rjust(10, '*')
# Out:
# '*****Hello'

# %%
'Hello'.center(20, '-')
# Out:
# '-------Hello--------'

# %% [markdown]
# ## Removing Whitespace with the strip(), rstrip(), and lstrip() Methods (IMPORTANT!)

# %%
spam = '    Hello, world!    '

# %%
spam.strip()
# Out:
# 'Hello, world!'

# %%
eggs = 'Hello, world!'

# %%
eggs.rstrip('!')
# Out:
# 'Hello, world'

# %% [markdown]
# ## Numeric Values of Characters with the ord() and chr() Functions
#
# - math operation of characters
#
# - PyCon talk, “Pragmatic Unicode, or, How Do I Stop
# the Pain?” at https://youtu.be/sgHbC6udIqc.

# %%
ord('A')
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %% [markdown]
# ## Copying and Pasting Strings with the pyperclip Module
#
# - copy() function
# - paste() function
